# %%
# Agent A: 并发写入测试
import time
print("Agent A 写入 cell-0")
print(f"时间戳: {time.time()}")

# %% [markdown]
# # Agent B: 并发写入测试
# import datetime
# print("Agent B 写入 cell-1")
# print(f"时间: {datetime.datetime.now()}")

# %% [markdown]
# ## Data Analysis

# %%
print('hello from cell-003')

# %%
high = data[data['score'] > 80]
print(high)
# Out:
#     name  score
# 0  Alice     85
# 1    Bob     92
