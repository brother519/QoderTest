# %% [markdown]
# # Demo Notebook
# This is a tool demo.

# %%
# NotebookEdit 工具演示
games = ['snake', 'tetris', 'minesweeper', 'puzzle-2048', 'sokoban', 'sudoku']
print(f'项目中共有 {len(games)} 个游戏:')
for g in games:
    print(f'  🎮 {g}')

# %%
import math, datetime
print(f"Pi = {math.pi:.4f}")
print(f"Demo time = {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
